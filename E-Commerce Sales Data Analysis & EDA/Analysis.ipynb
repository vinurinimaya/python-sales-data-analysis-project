# %%
## Loading the data set

import pandas as pd

df_sales = pd.read_csv('Python_Project_Sales_Data - Final.csv')

# %%
## EDA

df_sales.head()
# Out:
#    OrderID   OrderDate  CustomerID   Age    City CustomerSegment  ProductID  \
# 0   500001  2025-08-28      103695  36.0     Qom         Regular       2003
# 1   500002  2024-05-31      107935  49.0  Kerman         Regular       2014
# 2   500003  2025-08-10      105141  36.0  Tehran         Regular       2002
# 3   500004  2024-10-11      108780  45.0  Shiraz         Regular       2012
# 4   500005  2024-02-19      101187  24.0   Karaj         Regular       2008
#
#            ProductName     Category  UnitPrice  Quantity  Discount  \
# 0          USB-C Cable  Accessories          9       4.0       0.1
# 1             Backpack  Accessories         42       1.0       0.1
# 2  Mechanical Keyboard  Electronics         62       1.0       0.2
# 3         Office Chair  Home Office        180       1.0       0.1
# 4           Phone Case  Accessories         14       2.0       0.0
#
#   PaymentMethod PaymentDate PaymentStatus     Status
# ...
